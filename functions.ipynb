# %%
def function_name(parameter):
  "optional documentation string - used to describe the function"
  print("Hola " + parameter)

# %%
function_name("Matt")
# Out:
# Hola Matt

# %%
numbers = [12, 14, 25, 89, 23, 56, 22]

# %%
def calculate_mean(list):
  return sum(list) / len(list)

# %%
calculate_mean(numbers)
# Out:
# 34.42857142857143

# %%
def absolute(number):
  if number >= 0:
    return number
  else:
    return -number

# %%
n = -10
absolute(n)
# Out:
# 10
