# %%
import nltk

input_text = """Knowledge can be defined as awareness of facts or as practical skills, and may also refer to familiarity with objects or situations. Knowledge of facts, also called propositional knowledge, is often defined as true belief that is distinct from opinion or guesswork by virtue of justification. While there is wide agreement among philosophers that propositional knowledge is a form of true belief, many controversies in philosophy focus on justification: whether it is needed at all, how to understand it, and whether something else besides it is needed. These controversies intensified due to a series of thought experiments by Edmund Gettier and have provoked various alternative definitions. Some of them deny that justification is necessary and replace it, for example, with reliability or the manifestation of cognitive virtues. Others contend that justification is needed but formulate additional requirements, for example, that no defeaters of the belief are present or that the person would not have the belief if it was false."""

# %%
w = nltk.word_tokenize(input_text)
pos_tags = nltk.pos_tag(w)

# %%
pos_tags
# Out:
# [('Knowledge', 'NNP'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('defined', 'VBN'),
#  ('as', 'IN'),
#  ('awareness', 'NN'),
#  ('of', 'IN'),
#  ('facts', 'NNS'),
#  ('or', 'CC'),
#  ('as', 'IN'),
#  ('practical', 'JJ'),
#  ('skills', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('may', 'MD'),
#  ('also', 'RB'),
#  ('refer', 'VB'),
#  ('to', 'TO'),
#  ('familiarity', 'NN'),
#  ('with', 'IN'),
#  ('objects', 'NNS'),
#  ('or', 'CC'),
#  ('situations', 'NNS'),
#  ('.', '.'),
#  ('Knowledge', 'NNP'),
#  ('of', 'IN'),
#  ('facts', 'NNS'),
#  (',', ','),
#  ('also', 'RB'),
#  ('called', 'VBD'),
#  ('propositional', 'JJ'),
#  ('knowledge', 'NN'),
#  (',', ','),
#  ('is', 'VBZ'),
#  ('often', 'RB'),
#  ('defined', 'VBN'),
#  ('as', 'IN'),
#  ('true', 'JJ'),
#  ('belief', 'NN'),
#  ('that', 'WDT'),
#  ('is', 'VBZ'),
#  ('distinct', 'JJ'),
#  ('from', 'IN'),
#  ('opinion', 'NN'),
#  ('or', 'CC'),
#  ('guesswork', 'NN'),
#  ('by', 'IN'),
#  ('virtue', 'NN'),
#  ('of', 'IN'),
#  ('justification', 'NN'),
#  ('.', '.'),
#  ('While', 'IN'),
#  ('there', 'EX'),
#  ('is', 'VBZ'),
#  ('wide', 'JJ'),
#  ('agreement', 'NN'),
#  ('among', 'IN'),
#  ('philosophers', 'NNS'),
#  ('that', 'WDT'),
#  ('propositional', 'JJ'),
#  ('knowledge', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('form', 'NN'),
#  ('of', 'IN'),
#  ('true', 'JJ'),
#  ('belief', 'NN'),
#  (',', ','),
#  ('many', 'JJ'),
#  ('controversies', 'NNS'),
#  ('in', 'IN'),
#  ('philosophy', 'NN'),
#  ('focus', 'NN'),
#  ('on', 'IN'),
#  ('justification', 'NN'),
#  (':', ':'),
#  ('whether', 'IN'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('needed', 'VBN'),
#  ('at', 'IN'),
#  ('all', 'DT'),
#  (',', ','),
#  ('how', 'WRB'),
#  ('to', 'TO'),
#  ('understand', 'VB'),
#  ('it', 'PRP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('whether', 'IN'),
#  ('something', 'NN'),
#  ('else', 'RB'),
#  ('besides', 'IN'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('needed', 'VBN'),
#  ('.', '.'),
#  ('These', 'DT'),
#  ('controversies', 'NNS'),
#  ('intensified', 'VBD'),
#  ('due', 'JJ'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('series', 'NN'),
#  ('of', 'IN'),
#  ('thought', 'JJ'),
#  ('experiments', 'NNS'),
#  ('by', 'IN'),
#  ('Edmund', 'NNP'),
#  ('Gettier', 'NNP'),
#  ('and', 'CC'),
#  ('have', 'VBP'),
#  ('provoked', 'VBN'),
#  ('various', 'JJ'),
#  ('alternative', 'JJ'),
#  ('definitions', 'NNS'),
#  ('.', '.'),
#  ('Some', 'DT'),
#  ('of', 'IN'),
#  ('them', 'PRP'),
#  ('deny', 'VBP'),
#  ('that', 'DT'),
#  ('justification', 'NN'),
#  ('is', 'VBZ'),
#  ('necessary', 'JJ'),
#  ('and', 'CC'),
#  ('replace', 'VB'),
#  ('it', 'PRP'),
#  (',', ','),
#  ('for', 'IN'),
#  ('example', 'NN'),
#  (',', ','),
#  ('with', 'IN'),
#  ('reliability', 'NN'),
#  ('or', 'CC'),
#  ('the', 'DT'),
#  ('manifestation', 'NN'),
#  ('of', 'IN'),
#  ('cognitive', 'JJ'),
#  ('virtues', 'NNS'),
#  ('.', '.'),
#  ('Others', 'NNS'),
#  ('contend', 'VBP'),
#  ('that', 'DT'),
#  ('justification', 'NN'),
#  ('is', 'VBZ'),
#  ('needed', 'VBN'),
#  ('but', 'CC'),
#  ('formulate', 'VBP'),
#  ('additional', 'JJ'),
#  ('requirements', 'NNS'),
#  (',', ','),
#  ('for', 'IN'),
#  ('example', 'NN'),
#  (',', ','),
#  ('that', 'IN'),
#  ('no', 'DT'),
#  ('defeaters', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('belief', 'NN'),
#  ('are', 'VBP'),
#  ('present', 'JJ'),
#  ('or', 'CC'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('person', 'NN'),
#  ('would', 'MD'),
#  ('not', 'RB'),
#  ('have', 'VB'),
#  ('the', 'DT'),
#  ('belief', 'NN'),
#  ('if', 'IN'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('false', 'JJ'),
#  ('.', '.')]

# %%
# defining the parts of speech that we want to appear together

# %%
seq = '''
Chunk:
{<NNP>+}
{<NN>+}
{<NNPS>+}'''

# %%
npc = nltk.RegexpParser(seq)
res = npc.parse(pos_tags)

# %%
print(res)
# Out:
# (S
#   (Chunk Knowledge/NNP)
#   can/MD
#   be/VB
#   defined/VBN
#   as/IN
#   (Chunk awareness/NN)
#   of/IN
#   facts/NNS
#   or/CC
#   as/IN
#   practical/JJ
#   skills/NNS
#   ,/,
#   and/CC
#   may/MD
#   also/RB
#   refer/VB
#   to/TO
#   (Chunk familiarity/NN)
#   with/IN
#   objects/NNS
#   or/CC
#   situations/NNS
#   ./.
#   (Chunk Knowledge/NNP)
#   of/IN
#   facts/NNS
#   ,/,
#   also/RB
#   called/VBD
#   propositional/JJ
#   (Chunk knowledge/NN)
#   ,/,
#   is/VBZ
#   often/RB
#   defined/VBN
#   as/IN
#   true/JJ
#   (Chunk belief/NN)
#   that/WDT
#   is/VBZ
#   distinct/JJ
#   from/IN
#   (Chunk opinion/NN)
#   or/CC
#   (Chunk guesswork/NN)
#   by/IN
#   (Chunk virtue/NN)
#   of/IN
#   (Chunk justification/NN)
#   ./.
#   While/IN
#   there/EX
#   is/VBZ
#   wide/JJ
#   (Chunk agreement/NN)
#   among/IN
#   philosophers/NNS
#   that/WDT
#   propositional/JJ
#   (Chunk knowledge/NN)
#   is/VBZ
#   a/DT
#   (Chunk form/NN)
#   of/IN
#   true/JJ
#   (Chunk belief/NN)
#   ,/,
#   many/JJ
#   controversies/NNS
#   in/IN
#   (Chunk philosophy/NN focus/NN)
#   on/IN
#   (Chunk justification/NN)
#   :/:
#   whether/IN
#   it/PRP
#   is/VBZ
#   needed/VBN
#   at/IN
#   all/DT
#   ,/,
#   how/WRB
#   to/TO
#   understand/VB
#   it/PRP
#   ,/,
#   and/CC
#   whether/IN
#   (Chunk something/NN)
#   else/RB
#   besides/IN
#   it/PRP
#   is/VBZ
#   needed/VBN
#   ./.
#   These/DT
#   controversies/NNS
#   intensified/VBD
#   due/JJ
#   to/TO
#   a/DT
#   (Chunk series/NN)
#   of/IN
#   thought/JJ
#   experiments/NNS
#   by/IN
#   (Chunk Edmund/NNP Gettier/NNP)
#   and/CC
#   have/VBP
#   provoked/VBN
#   various/JJ
#   alternative/JJ
#   definitions/NNS
#   ./.
#   Some/DT
#   of/IN
#   them/PRP
#   deny/VBP
#   that/DT
#   (Chunk justification/NN)
#   is/VBZ
#   necessary/JJ
#   and/CC
#   replace/VB
#   it/PRP
#   ,/,
#   for/IN
#   (Chunk example/NN)
#   ,/,
#   with/IN
#   (Chunk reliability/NN)
#   or/CC
#   the/DT
#   (Chunk manifestation/NN)
#   of/IN
#   cognitive/JJ
#   virtues/NNS
#   ./.
#   Others/NNS
#   contend/VBP
#   that/DT
#   (Chunk justification/NN)
#   is/VBZ
#   needed/VBN
#   but/CC
#   formulate/VBP
#   additional/JJ
#   requirements/NNS
#   ,/,
#   for/IN
#   (Chunk example/NN)
#   ,/,
#   that/IN
#   no/DT
#   defeaters/NNS
#   of/IN
#   the/DT
#   (Chunk belief/NN)
#   are/VBP
#   present/JJ
#   or/CC
#   that/IN
#   the/DT
#   (Chunk person/NN)
#   would/MD
#   not/RB
#   have/VB
#   the/DT
#   (Chunk belief/NN)
#   if/IN
#   it/PRP
#   was/VBD
#   false/JJ
#   ./.)
