# %%
import nltk
nltk.download('averaged_perceptron_tagger')

input_text = """Knowledge can be defined as awareness of facts or as practical skills, and may also refer to familiarity with objects or situations. Knowledge of facts, also called propositional knowledge, is often defined as true belief that is distinct from opinion or guesswork by virtue of justification. While there is wide agreement among philosophers that propositional knowledge is a form of true belief, many controversies in philosophy focus on justification: whether it is needed at all, how to understand it, and whether something else besides it is needed. These controversies intensified due to a series of thought experiments by Edmund Gettier and have provoked various alternative definitions. Some of them deny that justification is necessary and replace it, for example, with reliability or the manifestation of cognitive virtues. Others contend that justification is needed but formulate additional requirements, for example, that no defeaters of the belief are present or that the person would not have the belief if it was false.
"""
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/user001/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
w = nltk.word_tokenize(input_text)

# %%
w
# Out:
# ['Knowledge',
#  'can',
#  'be',
#  'defined',
#  'as',
#  'awareness',
#  'of',
#  'facts',
#  'or',
#  'as',
#  'practical',
#  'skills',
#  ',',
#  'and',
#  'may',
#  'also',
#  'refer',
#  'to',
#  'familiarity',
#  'with',
#  'objects',
#  'or',
#  'situations',
#  '.',
#  'Knowledge',
#  'of',
#  'facts',
#  ',',
#  'also',
#  'called',
#  'propositional',
#  'knowledge',
#  ',',
#  'is',
#  'often',
#  'defined',
#  'as',
#  'true',
#  'belief',
#  'that',
#  'is',
#  'distinct',
#  'from',
#  'opinion',
#  'or',
#  'guesswork',
#  'by',
#  'virtue',
#  'of',
#  'justification',
#  '.',
#  'While',
#  'there',
#  'is',
#  'wide',
#  'agreement',
#  'among',
#  'philosophers',
#  'that',
#  'propositional',
#  'knowledge',
#  'is',
#  'a',
#  'form',
#  'of',
#  'true',
#  'belief',
#  ',',
#  'many',
#  'controversies',
#  'in',
#  'philosophy',
#  'focus',
#  'on',
#  'justification',
#  ':',
#  'whether',
#  'it',
#  'is',
#  'needed',
#  'at',
#  'all',
#  ',',
#  'how',
#  'to',
#  'understand',
#  'it',
#  ',',
#  'and',
#  'whether',
#  'something',
#  'else',
#  'besides',
#  'it',
#  'is',
#  'needed',
#  '.',
#  'These',
#  'controversies',
#  'intensified',
#  'due',
#  'to',
#  'a',
#  'series',
#  'of',
#  'thought',
#  'experiments',
#  'by',
#  'Edmund',
#  'Gettier',
#  'and',
#  'have',
#  'provoked',
#  'various',
#  'alternative',
#  'definitions',
#  '.',
#  'Some',
#  'of',
#  'them',
#  'deny',
#  'that',
#  'justification',
#  'is',
#  'necessary',
#  'and',
#  'replace',
#  'it',
#  ',',
#  'for',
#  'example',
#  ',',
#  'with',
#  'reliability',
#  'or',
#  'the',
#  'manifestation',
#  'of',
#  'cognitive',
#  'virtues',
#  '.',
#  'Others',
#  'contend',
#  'that',
#  'justification',
#  'is',
#  'needed',
#  'but',
#  'formulate',
#  'additional',
#  'requirements',
#  ',',
#  'for',
#  'example',
#  ',',
#  'that',
#  'no',
#  'defeaters',
#  'of',
#  'the',
#  'belief',
#  'are',
#  'present',
#  'or',
#  'that',
#  'the',
#  'person',
#  'would',
#  'not',
#  'have',
#  'the',
#  'belief',
#  'if',
#  'it',
#  'was',
#  'false',
#  '.']

# %%
tw = nltk.pos_tag(w)

# %%
tw
# Out:
# [('Knowledge', 'NNP'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('defined', 'VBN'),
#  ('as', 'IN'),
#  ('awareness', 'NN'),
#  ('of', 'IN'),
#  ('facts', 'NNS'),
#  ('or', 'CC'),
#  ('as', 'IN'),
#  ('practical', 'JJ'),
#  ('skills', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('may', 'MD'),
#  ('also', 'RB'),
#  ('refer', 'VB'),
#  ('to', 'TO'),
#  ('familiarity', 'NN'),
#  ('with', 'IN'),
#  ('objects', 'NNS'),
#  ('or', 'CC'),
#  ('situations', 'NNS'),
#  ('.', '.'),
#  ('Knowledge', 'NNP'),
#  ('of', 'IN'),
#  ('facts', 'NNS'),
#  (',', ','),
#  ('also', 'RB'),
#  ('called', 'VBD'),
#  ('propositional', 'JJ'),
#  ('knowledge', 'NN'),
#  (',', ','),
#  ('is', 'VBZ'),
#  ('often', 'RB'),
#  ('defined', 'VBN'),
#  ('as', 'IN'),
#  ('true', 'JJ'),
#  ('belief', 'NN'),
#  ('that', 'WDT'),
#  ('is', 'VBZ'),
#  ('distinct', 'JJ'),
#  ('from', 'IN'),
#  ('opinion', 'NN'),
#  ('or', 'CC'),
#  ('guesswork', 'NN'),
#  ('by', 'IN'),
#  ('virtue', 'NN'),
#  ('of', 'IN'),
#  ('justification', 'NN'),
#  ('.', '.'),
#  ('While', 'IN'),
#  ('there', 'EX'),
#  ('is', 'VBZ'),
#  ('wide', 'JJ'),
#  ('agreement', 'NN'),
#  ('among', 'IN'),
#  ('philosophers', 'NNS'),
#  ('that', 'WDT'),
#  ('propositional', 'JJ'),
#  ('knowledge', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('form', 'NN'),
#  ('of', 'IN'),
#  ('true', 'JJ'),
#  ('belief', 'NN'),
#  (',', ','),
#  ('many', 'JJ'),
#  ('controversies', 'NNS'),
#  ('in', 'IN'),
#  ('philosophy', 'NN'),
#  ('focus', 'NN'),
#  ('on', 'IN'),
#  ('justification', 'NN'),
#  (':', ':'),
#  ('whether', 'IN'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('needed', 'VBN'),
#  ('at', 'IN'),
#  ('all', 'DT'),
#  (',', ','),
#  ('how', 'WRB'),
#  ('to', 'TO'),
#  ('understand', 'VB'),
#  ('it', 'PRP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('whether', 'IN'),
#  ('something', 'NN'),
#  ('else', 'RB'),
#  ('besides', 'IN'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('needed', 'VBN'),
#  ('.', '.'),
#  ('These', 'DT'),
#  ('controversies', 'NNS'),
#  ('intensified', 'VBD'),
#  ('due', 'JJ'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('series', 'NN'),
#  ('of', 'IN'),
#  ('thought', 'JJ'),
#  ('experiments', 'NNS'),
#  ('by', 'IN'),
#  ('Edmund', 'NNP'),
#  ('Gettier', 'NNP'),
#  ('and', 'CC'),
#  ('have', 'VBP'),
#  ('provoked', 'VBN'),
#  ('various', 'JJ'),
#  ('alternative', 'JJ'),
#  ('definitions', 'NNS'),
#  ('.', '.'),
#  ('Some', 'DT'),
#  ('of', 'IN'),
#  ('them', 'PRP'),
#  ('deny', 'VBP'),
#  ('that', 'DT'),
#  ('justification', 'NN'),
#  ('is', 'VBZ'),
#  ('necessary', 'JJ'),
#  ('and', 'CC'),
#  ('replace', 'VB'),
#  ('it', 'PRP'),
#  (',', ','),
#  ('for', 'IN'),
#  ('example', 'NN'),
#  (',', ','),
#  ('with', 'IN'),
#  ('reliability', 'NN'),
#  ('or', 'CC'),
#  ('the', 'DT'),
#  ('manifestation', 'NN'),
#  ('of', 'IN'),
#  ('cognitive', 'JJ'),
#  ('virtues', 'NNS'),
#  ('.', '.'),
#  ('Others', 'NNS'),
#  ('contend', 'VBP'),
#  ('that', 'DT'),
#  ('justification', 'NN'),
#  ('is', 'VBZ'),
#  ('needed', 'VBN'),
#  ('but', 'CC'),
#  ('formulate', 'VBP'),
#  ('additional', 'JJ'),
#  ('requirements', 'NNS'),
#  (',', ','),
#  ('for', 'IN'),
#  ('example', 'NN'),
#  (',', ','),
#  ('that', 'IN'),
#  ('no', 'DT'),
#  ('defeaters', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('belief', 'NN'),
#  ('are', 'VBP'),
#  ('present', 'JJ'),
#  ('or', 'CC'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('person', 'NN'),
#  ('would', 'MD'),
#  ('not', 'RB'),
#  ('have', 'VB'),
#  ('the', 'DT'),
#  ('belief', 'NN'),
#  ('if', 'IN'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('false', 'JJ'),
#  ('.', '.')]

# %%
final_tag=[]
for i in tw:
    final_tag.append(i[0] + "_" + i[1])

# %%
final_tag
# Out:
# ['Knowledge_NNP',
#  'can_MD',
#  'be_VB',
#  'defined_VBN',
#  'as_IN',
#  'awareness_NN',
#  'of_IN',
#  'facts_NNS',
#  'or_CC',
#  'as_IN',
#  'practical_JJ',
#  'skills_NNS',
#  ',_,',
#  'and_CC',
#  'may_MD',
#  'also_RB',
#  'refer_VB',
#  'to_TO',
#  'familiarity_NN',
#  'with_IN',
#  'objects_NNS',
#  'or_CC',
#  'situations_NNS',
#  '._.',
#  'Knowledge_NNP',
#  'of_IN',
#  'facts_NNS',
#  ',_,',
#  'also_RB',
#  'called_VBD',
#  'propositional_JJ',
#  'knowledge_NN',
#  ',_,',
#  'is_VBZ',
#  'often_RB',
#  'defined_VBN',
#  'as_IN',
#  'true_JJ',
#  'belief_NN',
#  'that_WDT',
#  'is_VBZ',
#  'distinct_JJ',
#  'from_IN',
#  'opinion_NN',
#  'or_CC',
#  'guesswork_NN',
#  'by_IN',
#  'virtue_NN',
#  'of_IN',
#  'justification_NN',
#  '._.',
#  'While_IN',
#  'there_EX',
#  'is_VBZ',
#  'wide_JJ',
#  'agreement_NN',
#  'among_IN',
#  'philosophers_NNS',
#  'that_WDT',
#  'propositional_JJ',
#  'knowledge_NN',
#  'is_VBZ',
#  'a_DT',
#  'form_NN',
#  'of_IN',
#  'true_JJ',
#  'belief_NN',
#  ',_,',
#  'many_JJ',
#  'controversies_NNS',
#  'in_IN',
#  'philosophy_NN',
#  'focus_NN',
#  'on_IN',
#  'justification_NN',
#  ':_:',
#  'whether_IN',
#  'it_PRP',
#  'is_VBZ',
#  'needed_VBN',
#  'at_IN',
#  'all_DT',
#  ',_,',
#  'how_WRB',
#  'to_TO',
#  'understand_VB',
#  'it_PRP',
#  ',_,',
#  'and_CC',
#  'whether_IN',
#  'something_NN',
#  'else_RB',
#  'besides_IN',
#  'it_PRP',
#  'is_VBZ',
#  'needed_VBN',
#  '._.',
#  'These_DT',
#  'controversies_NNS',
#  'intensified_VBD',
#  'due_JJ',
#  'to_TO',
#  'a_DT',
#  'series_NN',
#  'of_IN',
#  'thought_JJ',
#  'experiments_NNS',
#  'by_IN',
#  'Edmund_NNP',
#  'Gettier_NNP',
#  'and_CC',
#  'have_VBP',
#  'provoked_VBN',
#  'various_JJ',
#  'alternative_JJ',
#  'definitions_NNS',
#  '._.',
#  'Some_DT',
#  'of_IN',
#  'them_PRP',
#  'deny_VBP',
#  'that_DT',
#  'justification_NN',
#  'is_VBZ',
#  'necessary_JJ',
#  'and_CC',
#  'replace_VB',
#  'it_PRP',
#  ',_,',
#  'for_IN',
#  'example_NN',
#  ',_,',
#  'with_IN',
#  'reliability_NN',
#  'or_CC',
#  'the_DT',
#  'manifestation_NN',
#  'of_IN',
#  'cognitive_JJ',
#  'virtues_NNS',
#  '._.',
#  'Others_NNS',
#  'contend_VBP',
#  'that_DT',
#  'justification_NN',
#  'is_VBZ',
#  'needed_VBN',
#  'but_CC',
#  'formulate_VBP',
#  'additional_JJ',
#  'requirements_NNS',
#  ',_,',
#  'for_IN',
#  'example_NN',
#  ',_,',
#  'that_IN',
#  'no_DT',
#  'defeaters_NNS',
#  'of_IN',
#  'the_DT',
#  'belief_NN',
#  'are_VBP',
#  'present_JJ',
#  'or_CC',
#  'that_IN',
#  'the_DT',
#  'person_NN',
#  'would_MD',
#  'not_RB',
#  'have_VB',
#  'the_DT',
#  'belief_NN',
#  'if_IN',
#  'it_PRP',
#  'was_VBD',
#  'false_JJ',
#  '._.']

# %%
final_para = ' '.join(final_tag)

# %%
final_para
# Out:
# 'Knowledge_NNP can_MD be_VB defined_VBN as_IN awareness_NN of_IN facts_NNS or_CC as_IN practical_JJ skills_NNS ,_, and_CC may_MD also_RB refer_VB to_TO familiarity_NN with_IN objects_NNS or_CC situations_NNS ._. Knowledge_NNP of_IN facts_NNS ,_, also_RB called_VBD propositional_JJ knowledge_NN ,_, is_VBZ often_RB defined_VBN as_IN true_JJ belief_NN that_WDT is_VBZ distinct_JJ from_IN opinion_NN or_CC guesswork_NN by_IN virtue_NN of_IN justification_NN ._. While_IN there_EX is_VBZ wide_JJ agreement_NN among_IN philosophers_NNS that_WDT propositional_JJ knowledge_NN is_VBZ a_DT form_NN of_IN true_JJ belief_NN ,_, many_JJ controversies_NNS in_IN philosophy_NN focus_NN on_IN justification_NN :_: whether_IN it_PRP is_VBZ needed_VBN at_IN all_DT ,_, how_WRB to_TO understand_VB it_PRP ,_, and_CC whether_IN something_NN else_RB besides_IN it_PRP is_VBZ needed_VBN ._. These_DT controversies_NNS intensified_VBD due_JJ to_TO a_DT series_NN of_IN thought_JJ experiments_NNS by_IN Edmund_NNP Gettier_NNP and_CC have_VBP provoked_VBN various_JJ alternative_JJ definitions_NNS ._. Some_DT of_IN them_PRP deny_VBP that_DT justification_NN is_VBZ necessary_JJ and_CC replace_VB it_PRP ,_, for_IN example_NN ,_, with_IN reliability_NN or_CC the_DT manifestation_NN of_IN cognitive_JJ virtues_NNS ._. Others_NNS contend_VBP that_DT justification_NN is_VBZ needed_VBN but_CC formulate_VBP additional_JJ requirements_NNS ,_, for_IN example_NN ,_, that_IN no_DT defeaters_NNS of_IN the_DT belief_NN are_VBP present_JJ or_CC that_IN the_DT person_NN would_MD not_RB have_VB the_DT belief_NN if_IN it_PRP was_VBD false_JJ ._.'

# %%
nltk.pos_tag(nltk.word_tokenize("I think he is right"))
# Out:
# [('I', 'PRP'), ('think', 'VBP'), ('he', 'PRP'), ('is', 'VBZ'), ('right', 'JJ')]

# %%
nltk.pos_tag(nltk.word_tokenize("Right is the clinic"))
# Out:
# [('Right', 'NNP'), ('is', 'VBZ'), ('the', 'DT'), ('clinic', 'NN')]
