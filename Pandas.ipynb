# %%
import pandas as pd
import numpy as np

# %%
pd.DataFrame([1,2,3])
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
pd.DataFrame([1,2,3])
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
pd.DataFrame({"Michael": [1,2,3]}, index=[3,4,5])

# %%
df = pd.read_csv("train.csv")
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df = pd.read_csv(
filepath_or_buffer="train.csv",
sep=',',
header=0, # or None
names=list(range(0,81)),
skiprows=0,
nrows=10, # Number of rows to read
parse_dates=[1,2,3] # parsing columns 1,2,3
)

# %%
# df1=pd.read_excel()
# df1=pd.read_html()
# df1=pd.read_json()
# df1=pd.read_parquet()
# df1=pd.read_sql()
# df1=pd.read_table()

# %%
dfs=[]
for filename in ["train.csv", "test.csv"]:
    df = pd.read_csv(filename, index_col=None, header=0)
    dfs.append(df)
df_multiple = pd.concat(dfs, axis=0, ignore_index=True)

# %%
df_multiple.shape

# %%
df.axes

# %%
df.T

# %%
df.T.shape

# %%
df.columns

# %%
df.dtypes # df.info(verbose=True) for complete list

# %%
df.empty

# %%
df.ndim

# %%
df.size # number of elements rows times cols

# %%
df.values

# %%
df.iat[0,2]

# %%
df.Fence # Selects the Fence column and returns a pandas series

# %%
df['Fence'] # returns a pandas series

# %%
df[['LotShape', 'LandContour']] # returns a dataframe of the selected columns ;; no need to be consecutive in the original

# %%
mask = df.SalePrice > 181500

# %%
df[mask]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
#
# ...

# %%
df.SalePrice > 181500 # returns a bool series
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1455    False
# 1456     True
# 1457     True
# 1458    False
# 1459    False
# Name: SalePrice, Length: 1460, dtype: bool

# %%
df[df.SalePrice > 181500]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
#
# ...

# %%
df[(df.SalePrice < 210000) & (df.SalePrice > 181500)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 28      29          20       RL         47.0    16321   Pave   NaN      IR1
# 57      58          60       RL         89.0    11645   Pave   NaN      IR1
# 62      63         120       RL         44.0     6442   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1430  1431          60       RL         60.0    21930   Pave   NaN      IR3
# 1433  1434          60       RL         93.0    10261   Pave   NaN      IR1
# 1439  1440          60       RL         80.0    11584   Pave   NaN      Reg
# 1440  1441          70       RL         79.0    11526   Pave   NaN      IR1
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
#
# ...

# %%
df[~((df.SalePrice < 210000) | (df.SalePrice > 181500))]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %%
df.SalePrice.isin([181500, 210000])
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456     True
# 1457    False
# 1458    False
# 1459    False
# Name: SalePrice, Length: 1460, dtype: bool

# %%
df[df.SalePrice.isin([181500, 210000])]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 216    217          20       RL         65.0     8450   Pave   NaN      Reg
# 444    445          60       RL         70.0     8750   Pave   NaN      Reg
# 453    454          60       FV         75.0     9000   Pave   NaN      Reg
# 546    547          50       RL         70.0     8737   Pave   NaN      IR1
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 216          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 444          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 453          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
df.loc[(df.SalePrice < 210000) & (df.SalePrice > 181500), 'SalePrice']
# Out:
# 0       208500
# 7       200000
# 28      207500
# 57      196500
# 62      202500
#          ...
# 1430    192140
# 1433    186500
# 1439    197000
# 1440    191000
# 1454    185000
# Name: SalePrice, Length: 166, dtype: int64

# %%
df.loc[(df.SalePrice < 210000) & (df.SalePrice > 181500), :]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 28      29          20       RL         47.0    16321   Pave   NaN      IR1
# 57      58          60       RL         89.0    11645   Pave   NaN      IR1
# 62      63         120       RL         44.0     6442   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1430  1431          60       RL         60.0    21930   Pave   NaN      IR3
# 1433  1434          60       RL         93.0    10261   Pave   NaN      IR1
# 1439  1440          60       RL         80.0    11584   Pave   NaN      Reg
# 1440  1441          70       RL         79.0    11526   Pave   NaN      IR1
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
#
# ...

# %%
df.loc[:, ['LotShape', 'LandContour']]
# Out:
#      LotShape LandContour
# 0         Reg         Lvl
# 1         Reg         Lvl
# 2         IR1         Lvl
# 3         IR1         Lvl
# 4         IR1         Lvl
# ...       ...         ...
# 1455      Reg         Lvl
# 1456      Reg         Lvl
# 1457      Reg         Lvl
# 1458      Reg         Lvl
# 1459      Reg         Lvl
#
# [1460 rows x 2 columns]

# %%
df.iloc[0,0]
# Out:
# 1

# %%
df.iloc[:,:]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.iloc[:,-1]
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
df.iloc[2:4,5:10] # Selection based on index
# Out:
#   Street Alley LotShape LandContour Utilities
# 2   Pave   NaN      IR1         Lvl    AllPub
# 3   Pave   NaN      IR1         Lvl    AllPub

# %%
df.iloc[2:4,:] # referring to all values
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
#
# [2 rows x 81 columns]
